# %% [markdown]
# <a href="https://colab.research.google.com/github/nikolaiborbe/VITBER_prosjekt2/blob/main/Prosjekt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prosjekt 2
#
# ## Oppgave 1a)
# For å vise at
# $$
# \phi(x,t)=\frac{1}{\sqrt{4\pi Dt}}\int_{-\infty}^\infty \mathrm{dy} \, h(y) \, e^{-\frac{(x-y)^2}{4Dt}}
# $$
#
# løser
# $$
# \frac{∂\phi}{∂t}=D\frac{∂^2\phi}{∂x^2}
# $$
#
# defineres først $C(t)=\frac{1}{\sqrt{4\pi Dt}}$ og $f(x,t)=h(y) \, e^{-\frac{(x-y)^2}{4Dt}}$, slik at $\phi=C*\int_{-\infty}^\infty f\mathrm{dy}$. De aktuelle partiellderiverte er vist under, der vi har brukt kjerneregelen og produktregelen for derivasjon.
#
# $$
# \frac{∂C}{∂t}=-\frac{1}{\sqrt{4\pi D}}*\frac{1}{2t^{3/2}}=-\frac{C}{2t}
# $$
#
# $$
# \frac{∂f}{∂t}=\frac{(x-y)^2}{4Dt^2}f
# $$
#
# $$
# \frac{∂f}{∂x}=-\frac{2(x-y)}{4Dt}f=-\frac{(x-y)}{2Dt}f
# $$
#
# $$
# \frac{∂^2f}{∂x^2}=-\frac{1}{2Dt}f-\frac{(x-y)}{2Dt}*\frac{∂f}{∂x}=-\frac{1}{2Dt}f+\frac{(x-y)}{2Dt}*\frac{(x-y)}{2Dt}f=f\left(\frac{(x-y)^2}{4D^2t^2}-\frac{1}{2Dt}\right)
# $$
#
# Anta at $h(y)$ er slik at $\int_{-\infty}^\infty f\mathrm{dy}$ er leddvis deriverbar. Da er $\frac{∂\phi}{∂t}=\frac{∂}{∂t}\left(C*\int_{-\infty}^\infty f\mathrm{dy}\right)=$

# %% [markdown]
# ## Oppgave 1c)
#
# Vi ser ved å sette $\beta^{-1} = k_b T \gg |V(x+1)-V(x)|$ får vi at,
#
# $$
# p^+=\frac{1}{1+e^{-\beta[V(x_0-1)-V(x_0+1)]}+e^{-\beta[V(x_0)-V(x_0+1)]}} \to
# $$
